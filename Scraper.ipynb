# %%
# Scraping
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style

# %%
url = ('https://finance.yahoo.com/quote/TSLA/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAAwvUZ_YFndkXlEf1aBC_uesGbNsqB7H5H4x5t8iZb8UgBZYFkrRqQ8wM8Yd6rWV1JAe7JDQIOauN1DqRQwy2zJERXOb_Gnz7B8UvMIdVtHS7iTMQD0pSXyD4NCv5L4bDMhM-OuuLLDLGvxofIJqKOXF8tn8_NPdVM6gdZYpN4BH')

r = requests.get(url)

# %%
print(r.text)
# Out:
# <!doctype html>
# <html lang="en-US" theme="light" data-color-scheme="light" class="desktop neo-green dock-upscale failsafe">
#     <head>
#         <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="oath:guce:consent-host" content="guce.yahoo.com">
# ...

# %%
web_content = BeautifulSoup(r.text, 'lxml')
web_content = web_content.find('div', class_='container yf-mgkamr')

print(web_content)
# Out:
# <div class="container yf-mgkamr"><fin-streamer active="" class="livePrice yf-mgkamr" data-field="regularMarketPrice" data-pricehint="2" data-symbol="TSLA" data-testid="qsp-price" data-trend="none" data-value="250.73"><span>250.73</span></fin-streamer> <fin-streamer active="" class="priceChange yf-mgkamr" data-field="regularMarketChange" data-pricehint="2" data-symbol="TSLA" data-testid="qsp-price-change" data-trend="txt" data-value="-0.7799988"><span class="txt-negative change yf-mgkamr">-0.78</span></fin-streamer> <fin-streamer active="" class="priceChange yf-mgkamr" data-field="regularMarketChangePercent" data-pricehint="2" data-symbol="TSLA" data-template="({fmt})" data-testid="qsp-price-change-percent" data-trend="txt" data-value="-0.31012636"><span class="txt-negative change yf-mgkamr">(-0.31%)</span></fin-streamer></div>

# %%
web_content = web_content.find('span').text
web_content
# Out:
# '250.73'

# %%
def real_time_price(stock_code):
    url = ('https://finance.yahoo.com/quote/') + stock_code
    r = requests.get(url)
    web_content = BeautifulSoup(r.text, 'lxml')
    web_content = web_content.find('div', class_='container yf-mgkamr')
    web_content = web_content.find('span').text

    if web_content == []: # if it's empty, assign default value
        web_content = '99999'

    return web_content

companies = ['TSLA', 'NFLX', 'AMZN', 'META']

for step in range(1, 101):
    price = []
    col = []
    time_stamp = datetime.datetime.now()
    time_stamp = time_stamp.strftime("%Y-%m-%d %H:%M:%S")
    for stock_code in companies:
        price.append(real_time_price(stock_code))
    col = [time_stamp]
    col.extend(price)
    df = pd.DataFrame(col)
    df = df.T
    df.to_csv('real time stock data.csv', mode='a', header = False)
    print(col)
# Out:
# ['2024-07-23 10:04:07', '249.43', '642.98', '187.50', '489.78', '184.56']
# ['2024-07-23 10:04:11', '249.35', '642.98', '187.85', '489.78', '184.56']
# ['2024-07-23 10:04:14', '249.43', '643.72', '187.50', '489.78', '184.56']
# ['2024-07-23 10:04:17', '249.43', '643.72', '187.50', '489.78', '184.56']
# ['2024-07-23 10:04:19', '249.43', '643.72', '187.50', '489.78', '184.56']
# ['2024-07-23 10:04:21', '249.43', '643.72', '187.50', '489.78', '184.56']
# ['2024-07-23 10:04:24', '249.43', '643.72', '187.85', '489.78', '184.56']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-a621fb28435c> in <module>
#      19     time_stamp = time_stamp.strftime("%Y-%m-%d %H:%M:%S")
#      20     for stock_code in companies:
# ---> 21         price.append(real_time_price(stock_code))
#      22     col = [time_stamp]
#      23     col.extend(price)
#
# ...

# %%
# Animation
style.use('fivethirtyeight')
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

def animate(i):
    df = pd.read_csv('real time stock data.csv')
    for i in range(1, 5):
        ys = df.iloc[1:, [i+1]].values
        xs = list(range(1, len(ys)+1))
        ax[i].clear()
        ax[i].plot(xs, ys)
        ax[i].set_title(companies[i-1], fontsize=12)

ani = animation.FuncAnimation(fig, animate, interval = 1000)

plt.tight_layout()
plt.show()
